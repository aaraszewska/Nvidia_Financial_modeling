# %% [markdown]
# # Nvidia Finance Modeling for Investment analysis
#
# # Financial Model to forecast performance

# %%
import pandas as pd  #import libraries

# %%
#loading files

file_path = "IncomeStatment.xlsx"
income_statment = pd.read_excel(file_path,sheet_name = "IncomeStatment")
balance_sheet = pd.read_excel(file_path,sheet_name= "Balance_sheet")
cash_flow = pd.read_excel(file_path,sheet_name = "cash_flow")

# %%
income_statment
# Out:
#                                                 Meric 1/26/2025  1/28/2024  \
# 0                                             Revenue    130497   60922.00
# 1                                     Cost of revemue     32639   16621.00
# 2                                        Gross profit     97858   44301.00
# 3                            Research and development     12914    8675.00
# 4                   Sales, general and administrative      3491    2654.00
# 5                        Acquisition termination cost         0       0.00
# 6                            Total operating expenses     16405   11329.00
# 7                                    Operating income     81453   32972.00
# 8                                     Interest income      1786     866.00
# 9                                    Interest expense      -247    -257.00
# 10                                         Other, net      1034     237.00
# ...

# %%
balance_sheet
# Out:
#                                            Metric 26-Jan-25  28-Jan-24
# 0        Cash and cash equivalents current assert      8589       7280
# 1            Marketable securities current assert     34621      18704
# 2         Accounts receivable, net current assert     23065       9999
# 3                      Inventories current assert     10080       5282
# 4       Prepaid expenses and other current assets      3771       3080
# 5                            Total current assets     80126      44345
# 6                     Property and equipment, net      6283       3914
# 7                          Operating lease assets      1793       1346
# 8                                        Goodwill      5188       4430
# 9                          Intangible assets, net       807       1112
# 10                     Deferred income tax assets     10979       6081
# 11                                   Other assets      6425       4500
# ...

# %%
cash_flow
# Out:
#                                                Metric  26-Jan-25  28-Jan-24  \
# 0                                          Net income      72880      29760
# 1                    Stock-based compensation expense       4737       3549
# 2                       Depreciation and amortization       1864       1508
# 3                               Deferred income taxes      -4477      -2489
# 4                publicly-held equity securities, net      -1030       -238
# 5                        Acquisition termination cost          0          0
# 6                                               Other       -502       -278
# 7                                 Accounts receivable     -13063      -6172
# 8                                         Inventories      -4781        -98
# 9                   Prepaid expenses and other assets       -395      -1522
# 10                                   Accounts payable       3357       1531
# ...

# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import yfinance as yf #market trends

nvda = yf.Ticker("NVDA")
df = nvda.history(period="5y")  # Last 5 years of data
df.to_csv("nvda_stock.csv")  # Save for further analysis

# %%
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-03-27 00:00:00-04:00    6.227058    6.553854    6.194179    6.295057
# 2020-03-30 00:00:00-04:00    6.360565    6.624593    6.316478    6.615376
# 2020-03-31 00:00:00-04:00    6.655479    6.859727    6.420096    6.565810
# 2020-04-01 00:00:00-04:00    6.367789    6.514249    6.009858    6.054443
# 2020-04-02 00:00:00-04:00    6.083586    6.376507    6.035513    6.363306
# ...                               ...         ...         ...         ...
# 2025-03-21 00:00:00-04:00  116.940002  117.989998  115.419998  117.699997
# 2025-03-24 00:00:00-04:00  119.879997  122.220001  119.339996  121.410004
# 2025-03-25 00:00:00-04:00  120.550003  121.290001  118.919998  120.690002
# 2025-03-26 00:00:00-04:00  118.730003  118.839996  112.709999  113.760002
# 2025-03-27 00:00:00-04:00  111.345001  114.449997  110.669998  111.964996
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
df = df.reset.index() #reset index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13692\4049848816.py in ?()
# ----> 1 df = df.reset.index() #reset index
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'reset'

# %%
df['Date'] = df['Date'].dt.strftime("%d-%b-%y") #date with correct format
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 df['Date'] = df['Date'].dt.strftime("%d-%b-%y")
#
# ...

# %%
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-03-27 00:00:00-04:00    6.227058    6.553854    6.194179    6.295057
# 2020-03-30 00:00:00-04:00    6.360565    6.624593    6.316478    6.615376
# 2020-03-31 00:00:00-04:00    6.655479    6.859727    6.420096    6.565810
# 2020-04-01 00:00:00-04:00    6.367789    6.514249    6.009858    6.054443
# 2020-04-02 00:00:00-04:00    6.083586    6.376507    6.035513    6.363306
# ...                               ...         ...         ...         ...
# 2025-03-21 00:00:00-04:00  116.940002  117.989998  115.419998  117.699997
# 2025-03-24 00:00:00-04:00  119.879997  122.220001  119.339996  121.410004
# 2025-03-25 00:00:00-04:00  120.550003  121.290001  118.919998  120.690002
# 2025-03-26 00:00:00-04:00  118.730003  118.839996  112.709999  113.760002
# 2025-03-27 00:00:00-04:00  111.345001  114.449997  110.669998  111.964996
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
# calculate revenue growth = (current period revenue -  previous period revenue) / previous period revenue * 100

income_statment['Revenue_growth'] = income_statment['revenue'].pct_change() * 100
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'revenue'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[133], line 3
# ...
